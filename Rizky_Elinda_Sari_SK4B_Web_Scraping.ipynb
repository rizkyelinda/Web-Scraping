# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google-play-scraper-1.0.5.tar.gz (52 kB)
#      |████████████████████████████████| 52 kB 1.1 MB/s
# Building wheels for collected packages: google-play-scraper
#   Building wheel for google-play-scraper (setup.py) ... done
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.5-py3-none-any.whl size=24484 sha256=41918532bc9c0c3092cbf6fcef904dd9e798ee534db1e46956c60bfe85d97a0a
#   Stored in directory: /root/.cache/pip/wheels/4a/26/18/48fda51f20c9e550c735fa6f3a6887dc8836f8d709a3cf8a9c
# Successfully built google-play-scraper
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.0.5

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.duolingo',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=85,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                             reviewId                userName  \
# 0  gp:AOqpTOGimlUU3FJSNp67jPe-aownkrOiKPudZt6n83K...       Bayu Gumilang 818
# 1  gp:AOqpTOH5YJPCgleBNwUCTRVV83zsPIqFYJrSxOtJhcR...     Wadhannisa Nulhakim
# 2  gp:AOqpTOEuyaP2b7AHpkwB0tPuC5t6J24YJqDXQmk1mvO...        Adelina Aquaviva
# 3  gp:AOqpTOHqhyYePqw_oOAL1thHG_zJwZ9XnHetI67B3uP...               Rey• Offc
# 4  gp:AOqpTOFwqM7WornkSXbi272vse3D-SNc_mcQssko6AA...  I Made Pasek Juniartha
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a/AATXAJ...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  Terimakasih Duo saya bisa belajar Bahasa Inggr...      5              0
# 1  Aplikasinya bagus kita bisa belajar berbagi ba...      5              0
# 2  Aplikasi duolingo sangat membantu saya untuk b...      5              0
# 3                                                 💕💕      5              0
# 4  Duolinggo sangat seru untuk di pelajari. dalam...      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0               5.53.3 2022-05-16 06:40:03         None      None
# 1               5.56.4 2022-05-16 06:31:44         None      None
# 2               5.56.4 2022-05-16 06:29:33         None      None
# 3               5.55.4 2022-05-16 05:23:58         None      None
# 4               5.55.4 2022-05-16 05:23:16         None      None

# %%
len(df_busu.index)
# Out:
# 85

# %%
df_busu[['userName', 'score', 'at', 'content']].head()
# Out:
#                  userName  score                  at  \
# 0       Bayu Gumilang 818      5 2022-05-16 06:40:03
# 1     Wadhannisa Nulhakim      5 2022-05-16 06:31:44
# 2        Adelina Aquaviva      5 2022-05-16 06:29:33
# 3               Rey• Offc      5 2022-05-16 05:23:58
# 4  I Made Pasek Juniartha      5 2022-05-16 05:23:16
#
#                                              content
# 0  Terimakasih Duo saya bisa belajar Bahasa Inggr...
# 1  Aplikasinya bagus kita bisa belajar berbagi ba...
# 2  Aplikasi duolingo sangat membantu saya untuk b...
# 3                                                 💕💕
# 4  Duolinggo sangat seru untuk di pelajari. dalam...

# %%
my_df = df_busu[['userName', 'score', 'at', 'content']]

# %%
my_df.to_csv("Data Scraping Ulasan.csv", index = False)
